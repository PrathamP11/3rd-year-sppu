# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Desktop/dsbda code/SPT.csv")
df
# Out:
#    gender math score reading score  writing score  placement score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
df.shape
# Out:
# (9, 7)

# %%
df.describe()
# Out:
#        writing score  placement score  placement offer count
# count       8.000000         8.000000               9.000000
# mean       77.000000        62.125000               1.777778
# std        13.416408        23.295846               1.201850
# min        52.000000        12.000000               0.000000
# 25%        72.250000        53.500000               1.000000
# 50%        76.500000        72.000000               2.000000
# 75%        88.250000        78.000000               2.000000
# max        93.000000        81.000000               4.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 9 non-null      object
#  1   math score             8 non-null      object
#  2   reading score          9 non-null      object
#  3   writing score          8 non-null      float64
#  4   placement score        8 non-null      float64
#  5   placement offer count  9 non-null      int64
#  6   Region                 8 non-null      object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 632.0+ bytes

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               1
# reading score            0
# writing score            1
# placement score          1
# placement offer count    0
# Region                   1
# dtype: int64

# %%
missing_values = ['Na','na']

# %%
df = pd.read_csv("Desktop/dsbda code/SPT.csv", na_values = missing_values)
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
df['math score'] = df['math score'].fillna(df['math score'].mean())
df['reading score'] = df['reading score'].fillna(df['reading score'].mean())
df['writing score'] = df['writing score'].fillna(df['writing score'].mean())
df['placement score'] = df['placement score'].fillna(df['placement score'].mean())

# %%
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0  female   72.000000          72.00           74.0           78.000
# 1  female   69.000000          90.00           88.0           62.125
# 2  female   90.000000          95.00           93.0           74.000
# 3    male   47.000000          57.00           77.0           78.000
# 4    male   52.285714          78.00           75.0           81.000
# 5  female   71.000000          72.25           78.0           70.000
# 6    male   12.000000          44.00           52.0           12.000
# 7    male   52.285714          65.00           67.0           49.000
# 8    male    5.000000          77.00           89.0           55.000
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['gender'] = label_encoder.fit_transform(df['gender'])

# %%
df['gender'].unique
# Out:
# <bound method Series.unique of 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    1
# 7    1
# 8    1
# Name: gender, dtype: int32>

# %%
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0       0   72.000000          72.00           74.0           78.000
# 1       0   69.000000          90.00           88.0           62.125
# 2       0   90.000000          95.00           93.0           74.000
# 3       1   47.000000          57.00           77.0           78.000
# 4       1   52.285714          78.00           75.0           81.000
# 5       0   71.000000          72.25           78.0           70.000
# 6       1   12.000000          44.00           52.0           12.000
# 7       1   52.285714          65.00           67.0           49.000
# 8       1    5.000000          77.00           89.0           55.000
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
#dropping null column
dfn = df.dropna(axis = 1)
#another method: dfn=df.drop(["Region"], axis=1)

# %%
dfn
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0       0   72.000000          72.00           74.0           78.000
# 1       0   69.000000          90.00           88.0           62.125
# 2       0   90.000000          95.00           93.0           74.000
# 3       1   47.000000          57.00           77.0           78.000
# 4       1   52.285714          78.00           75.0           81.000
# 5       0   71.000000          72.25           78.0           70.000
# 6       1   12.000000          44.00           52.0           12.000
# 7       1   52.285714          65.00           67.0           49.000
# 8       1    5.000000          77.00           89.0           55.000
#
#    placement offer count
# 0                      1
# 1                      2
# 2                      2
# 3                      1
# 4                      3
# 5                      4
# 6                      2
# 7                      1
# 8                      0

# %%
#Boxplot
col = ['math score', 'reading score' , 'writing score','placement score']
dfn.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(dfn['math score']<10))
print(np.where(dfn['reading score']<50))
print(np.where(dfn['writing score']<60))
print(np.where(dfn['placement score']<20))
# Out:
# (array([8], dtype=int64),)
# (array([6], dtype=int64),)
# (array([6], dtype=int64),)
# (array([6], dtype=int64),)

# %%
sample_outliers = [8,6];

# %%
#Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(dfn['placement score'], dfn['placement offer count'])
plt.show()

# %%
print(np.where((dfn['placement score']<50) & (dfn['placement offer count']>1)))
print(np.where((dfn['placement score']>50) & (dfn['placement offer count']<1)))
# Out:
# (array([6], dtype=int64),)
# (array([8], dtype=int64),)

# %%
import warnings
warnings.filterwarnings('ignore')
new_df=dfn
for i in sample_outliers:
    new_df.drop(i,inplace=True)
new_df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0       0   72.000000          72.00           74.0           78.000
# 1       0   69.000000          90.00           88.0           62.125
# 2       0   90.000000          95.00           93.0           74.000
# 3       1   47.000000          57.00           77.0           78.000
# 4       1   52.285714          78.00           75.0           81.000
# 5       0   71.000000          72.25           78.0           70.000
# 7       1   52.285714          65.00           67.0           49.000
#
#    placement offer count
# 0                      1
# 1                      2
# 2                      2
# 3                      1
# 4                      3
# 5                      4
# 7                      1

# %%
#data normalization
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x=dfn.iloc[:,1:5]

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized
# Out:
#           0         1         2         3
# 0  0.581395  0.394737  0.269231  0.906250
# 1  0.511628  0.868421  0.807692  0.410156
# 2  1.000000  1.000000  1.000000  0.781250
# 3  0.000000  0.000000  0.384615  0.906250
# 4  0.122924  0.552632  0.307692  1.000000
# 5  0.558140  0.401316  0.423077  0.656250
# 6  0.122924  0.210526  0.000000  0.000000
